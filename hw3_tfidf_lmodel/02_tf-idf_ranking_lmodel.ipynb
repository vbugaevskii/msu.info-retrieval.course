# %%
import re

from bs4 import BeautifulSoup

# %% [markdown]
# ## Загрузка HTML-страниц и извлечение предложений

# %%
from itertools import filterfalse

def extract_text(filename):
    from bs4 import Comment
    
    with open(filename, mode='r') as f_name:
        soup = BeautifulSoup(f_name, 'html.parser')
    
    for a in soup.find_all('a', href=True):
        a.replaceWithChildren()
    
    tags = soup.find_all(text=True)
    tags = filter(lambda t: t.parent.name not in {'script', 'style', 'head'}, tags)
    tags = filterfalse(lambda t: isinstance(t, Comment), tags)    
    tags = map(lambda t: t.replace('\xa0', ' '), tags)
    
    return ' '.join(tags)

# %%
SPACES_PATTERN = re.compile("\s+")
TEXT_PATTERN = re.compile("\w+")

def extract_sentences(text):
    splits = [0]
    
    braces = 0
    for i, c in enumerate(text):
        if c in '([{':
            braces += 1
        elif c in ')]}' and braces > 0:
            braces -= 1
        elif c == '.' and braces == 0:
            if i >= 3 and ' ' not in text[i-3:i-1]:
                splits.append(i + 1)
    splits.append(len(text))
    
    sentences = (text[i:j].strip() for i, j in zip(splits[:-1], splits[1:]))
    sentences = filter(None, map(lambda s: SPACES_PATTERN.sub(" ", s), sentences))
    sentences = filter(lambda s: TEXT_PATTERN.search(s), sentences)
    return list(sentences)

# %%
from itertools import chain

SPACES_REMOVE_AFTER_PATTERN  = re.compile("\s+(?=[.,;s?!\}\)\]»\"\'])")
SPACES_REMOVE_BEFORE_PATTERN = re.compile("(?<=[\{\(\[«\"\'])\s+")

def extract_sentences_from_text(text):
    text = SPACES_REMOVE_AFTER_PATTERN.sub("", text)
    text = SPACES_REMOVE_BEFORE_PATTERN.sub("", text)
    text = text.split('\n')
    text = filter(None, map(lambda s: s.strip(), text))
    text = chain(*map(extract_sentences, text))
    text = filter(lambda s: s.count(' ') > 3, text)
    return list(text)

# %%
import os

docs = []

for dirpath, dirnames, filenames in os.walk("dumps"):
    filenames = map(lambda f: os.path.join(dirpath, f), filenames)
    filenames = list(filenames)
    
for filename in filenames:
    text = extract_text(filename)
    sentences = extract_sentences_from_text(text)
    docs.extend(sentences)

# %%
len(docs)
# Out:
# 2866

# %% [markdown]
# ## Морфологическая предобработка предложений

# %%
import re

from functools import lru_cache

from pymorphy2 import MorphAnalyzer
from nltk.stem import WordNetLemmatizer

ru_morph = MorphAnalyzer()
en_morph = WordNetLemmatizer()

CYRILLIC_PATTERN = re.compile('[а-яА-Я]')
DIGIT_PATTERN = re.compile('\d+')

def has_cyrillic(text):
    return bool(CYRILLIC_PATTERN.search(text))

def has_numeric(text):
    return bool(DIGIT_PATTERN.search(text))

@lru_cache(maxsize=1500)
def morph_process(token):
    if has_cyrillic(token):
        return ru_morph.parse(token)[0].normal_form
    elif has_numeric(token):
        return token
    else:
        return en_morph.lemmatize(token)
    
def morph_sentence(sentence):
    res = re.findall('\d+', sentence.lower())
    words = re.findall('[^\W\d_]+', sentence.lower())
    res.extend(map(morph_process, words))
    return res

# %% [markdown]
# ## Текстовое ранжирование

# %%
# NOT IMPLEMENTED

from nltk.corpus import stopwords

ru_stopwords = stopwords.words('russian')
en_stopwords = stopwords.words('english')

stopwords_ = set(ru_stopwords) | set(en_stopwords)

# %% [markdown]
# ### TF-IDF

# %%
import numpy as np
from scipy.sparse import csr_matrix


class TfIdf:
    def __init__(self, preprocess, stopwords=None, idf=True, norm=True):
        self.preprocess_ = preprocess
        self.vocabulary_ = {}
        
        self._use_idf = idf
        self._use_norm = norm
        
    def _transform(self, docs, use_vocab=True):
        if not use_vocab:
            self.vocabulary_ = {}
        vocabulary = self.vocabulary_
        
        df_ = {}
        tf_, indices, indptr = [], [], [0]
        
        for doc_id, doc in enumerate(docs):
            tf_counts, df_entries = {}, set()
            
            for term in self.preprocess_(doc):                
                if term not in vocabulary:
                    if use_vocab:
                        continue
                    vocabulary[term] = len(vocabulary)
                term_id = vocabulary[term]
                
                if term_id not in tf_counts:
                    tf_counts[term_id] = 0
                tf_counts[term_id] += 1
                
                df_entries.add(term_id)
                
            indices.extend(tf_counts.keys())
            tf_.extend(tf_counts.values())
            indptr.append(len(indices))
            
            for term_id in df_entries:
                df_[term_id] = df_.get(term_id, 0) + 1
                
        tf_ = csr_matrix((tf_, indices, indptr), dtype=np.uint32,
                         shape=(len(docs), len(vocabulary)))
        tf_.sort_indices()
        tf_ = tf_.toarray()
        
        if self._use_norm:
            # norm = np.sqrt(np.power(tf_, 2).sum(axis=1, keepdims=True))
            norm = tf_.max(axis=1, keepdims=True)
            tf_ = tf_ / norm
        
        if not use_vocab:
            self.idf_ = [np.log10(len(docs) / float(df_[tid])) for tid in range(len(vocabulary))]
            self.idf_ = np.asarray(self.idf_)
        idf_ = self.idf_
        
        if self._use_idf:
            tf_ = tf_ * idf_.reshape(1, -1)
        
        return tf_
        
    def fit_transform(self, docs):
        return self._transform(docs, use_vocab=False)
    
    def fit(self, docs):
        _ = self.fit_transform(docs)
        return self
    
    def transform(self, docs):
        return self._transform(docs, use_vocab=True)

# %% [markdown]
# ### TF-IDF Ranker

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
class TfIdfRanker:
    def __init__(self, tfidf):
        self._ranker_tfidf = tfidf
    
    def load_docs(self, docs):
        self.forward_index = docs
        self.X_docs = self._ranker_tfidf.fit_transform(docs)
        
    def rank(self, *queries):
        X_docs  = self.X_docs
        X_query = self._ranker_tfidf.transform(*queries)
        
        ranks = cosine_similarity(X_query, X_docs)
        a_ranks = np.argsort(ranks, axis=1)[:,::-1]
        return [[(doc_id, ranks[qid, doc_id]) for doc_id in a_ranks[qid, :]]
                for qid in range(a_ranks.shape[0])]
    
    def print_serp(self, query, relevant_docs, top=10, norm=False):
        print("QUERY:", query)
        if norm:
            normed = self._ranker_tfidf.preprocess_(query)
            print("[NORMALIZED]")
            print(*normed)
        print("\n")
            
        ranks = self.rank([query])[0]
        
        for pos, (doc_id, rank) in enumerate(ranks[:top], 1):
            sent = self.forward_index[doc_id]
            mark = "[{}]".format('*' if doc_id in relevant_docs else 'o')
            
            print(f"POS:   {pos}")
            print(f"DOCID: {doc_id}")
            print(f"RANK:  {rank:.10f}")
            print()
            print(mark, sent)
            
            if norm:
                normed = self._ranker_tfidf.preprocess_(sent)
                print()
                print("[NORMALIZED]")
                print(*normed)
            
            print("=" * 80)
            
        return ranks

# %% [markdown]
# ### Language Model Ranker

# %%
class LangModelRanker:
    def __init__(self, lambda_=0.7):
        self._ranker_tfidf = TfIdf(preprocess=morph_sentence, idf=False)
        self.lambda_ = lambda_
    
    def load_docs(self, docs):
        self.forward_index = docs
        
        X_docs = self._ranker_tfidf.fit_transform(docs)
        
        # условная вероятность P(term|doc)
        self.p2doc = X_docs / X_docs.sum(axis=1).reshape(-1, 1)
        
        # условная вероятность P(term|model)
        self.p2model = X_docs.sum(axis=0)
        self.p2model = self.p2model / self.p2model.sum()
        
        self._probs = (1.0 - self.lambda_) * self.p2model + self.lambda_ * self.p2doc
        
    def rank(self, queries):        
        X_query = self._ranker_tfidf.transform(queries)
        
        ranks = []
        for qid in range(len(queries)):
            i_query = np.nonzero(X_query[qid])[0]
            rank = self._probs[:, i_query].prod(axis=1)
            ranks.append(rank)
        ranks = np.asarray(ranks)
            
        a_ranks = np.argsort(ranks, axis=1)[:,::-1]
        return [[(doc_id, ranks[qid, doc_id]) for doc_id in a_ranks[qid, :]]
                for qid in range(a_ranks.shape[0])]
    
    def print_serp(self, query, relevant_docs, top=10, norm=False, probs=False):
        print("QUERY:", query)
        if norm:
            normed = self._ranker_tfidf.preprocess_(query)
            print("[NORMALIZED]")
            print(*normed)
        print()
        
        if probs:
            X_query = self._ranker_tfidf.transform([query])
            i_query = np.nonzero(X_query[0])[0]
            v_inverse = {v: k for k, v in self._ranker_tfidf.vocabulary_.items()}
            for i in i_query:
                print("P({term}|model) = {prob:.5f}".format(term=v_inverse[i], prob=self.p2model[i]))
            print()
            
        ranks = self.rank([query])[0]
        
        for pos, (doc_id, rank) in enumerate(ranks[:top], 1):
            sent = self.forward_index[doc_id]
            mark = "[{}]".format('*' if doc_id in relevant_docs else 'o')
            
            print(f"POS:   {pos}")
            print(f"DOCID: {doc_id}")
            print(f"RANK:  {rank}")
            print()
            print(mark, sent)
            
            if norm:
                normed = self._ranker_tfidf.preprocess_(sent)
                print()
                print("[NORMALIZED]")
                print(*normed)
            
            print("=" * 80)
            
        return ranks

# %% [markdown]
# ### Метрики

# %%
from operator import itemgetter


def DCG_score(ranks_true, ranks_pred):
    score = 0
    for pos, (doc_id, rank) in enumerate(ranks_pred, 1):
        score += ranks_true.get(doc_id, 0) / np.log2(pos + 1)
    return score

def NDCG_score(ranks_true, ranks_pred):
    ranks_true_ = sorted(ranks_true.items(), key=itemgetter(1), reverse=True)
    
    dcg_curr = DCG_score(ranks_true, ranks_pred)
    dcg_best = DCG_score(ranks_true, ranks_true_)
    
    return dcg_curr / dcg_best

# %%
def count_metrics(ranks_true, ranks_pred):
    TP, TN, FP, FN = 0.0, 0.0, 0.0, 0.0
    
    docs_processed = set()
    
    for doc_id, rank in ranks_pred:
        y_pred = rank
        y_true = ranks_true.get(doc_id, 0) > 0

        TP += y_true and y_pred
        TN += not y_true and not y_pred
        FP += not y_true and y_pred
        FN += y_true and not y_pred
        
        docs_processed.add(doc_id)        

    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    fmeasure = 2.0 / (1.0 / recall + 1.0 / precision)
    ndcg_10 = NDCG_score(ranks_true, ranks_pred[:10])
    
    ndcg = NDCG_score(ranks_true, ranks_pred)
    
    return precision, recall, fmeasure, ndcg_10, ndcg

# %% [markdown]
# ### Запросы

# %%
queries = [
    "Лётчику понадобилось два десятка лет, чтобы повторно стать подполковником.",
    "Не вызвавший первоначально интереса экспертов «маленький рыжеволосый мальчик» " + \
        "(на илл.) выставлен на аукционе со стартовой ценой в миллион евро.",
    "Американский фотограф, известный съёмками высшего общества, был также личным " + \
        "фотографом знаменитого мафиозо.",
]

# %%
relevant_docs = [
    {146:  2, 148:  2, 149:  2, 165:  2, 180:  2},
    {2375: 1, 2389: 2, 2390: 2, 2392: 1, 2416: 2},
    {1161: 1, 2557: 2, 2581: 2, 2582: 2},
]

# %% [raw]
# for doc_id, d in enumerate(docs):
#     if 'Из общего ряда «гламурных»' in d:
#         print(doc_id)
#         print(d)

# %%
qid = 0

for doc_id in relevant_docs[qid]:
    print(f"docid#{doc_id}")
    print(docs[doc_id], '\n')
# Out:
# docid#146
# подполковник Российской императорской армии полковник Красной армии
#
# docid#148
# Николай Александрович Мульков (15 [27] ноября 1890 — не ранее 1952) — военный лётчик.
#
# docid#149
# Подполковник Российской императорской армии (1917), участник Первой мировой войны.
#
# docid#165
# 19 мая 1916 года Николай Мульков был произведён в чин штабс-капитана, 17 августа 1917 года в капитаны, а на следующий день — в подполковники.
#
# docid#180
# 11 сентября 1940 года получил звание подполковника, а 21 февраля 1945 года — полковника.

# %%
qid = 1

for doc_id in relevant_docs[qid]:
    print(f"docid#{doc_id}")
    print(docs[doc_id], '\n')
# Out:
# docid#2375
# «Ребёнок Иисус, стоящий на коленях перед орудиями Страстей» (фр. «Jésus enfant agenouillé devant les instruments de la Passion») — картина, находящаяся в частной коллекции в Вандее во Франции и атрибутируемая братьям Ленен или, по мнению некоторых искусствоведов, Матьё Ленену [1].
#
# docid#2389
# Владелица увидела Руйяков по телевидению; в разговоре по телефону она называла картину «Маленький рыжеволосый мальчик».
#
# docid#2390
# Она сообщила, что ряд парижских аукционистов, к которым она уже обращалась некоторое время назад, не заинтересовались картиной, ссылаясь на слабый интерес рынка к картинам на религиозный сюжет [6].
#
# docid#2392
# Он увидел картину висящей на стене, сразу определил её сюжет и оценил выдающиеся художественные достоинства [7].
#
# docid#2416
# Она оценивается от 3 до 5 млн евро (по другим данным, только в 1 млн евро [2]) — в три раза больше, чем картина «Святой Иероним», которая должна быть выставлена в апреле 2018 года на аукционе «Кристис» (1 млн долларов).

# %%
qid = 2

for doc_id in relevant_docs[qid]:
    print(f"docid#{doc_id}")
    print(docs[doc_id], '\n')
# Out:
# docid#1161
# Лаки Лучано был любимой моделью американского фотографа Слима Ааронса.
#
# docid#2557
# Джордж Аллен «Слим» Ааронс (29 октября 1916 — 30 мая 2006) — американский фотограф, известный съемками «красивой жизни» высшего общества, светских персон, кинозвёзд и прочих знаменитостей.
#
# docid#2581
# Из общего ряда «гламурных» персонажей, которых фотографировал Слим Ааронс, резко выделялся гангстер Чарльз Лучано по прозвищу «Lucky» («Счастливчик») — один из «боссов» итало-американской организованной преступности.
#
# docid#2582
# Ааронс следовал за ним повсюду, в том числе в Италию, и сделал множество снимков «крестного отца».

# %% [markdown]
# ### Модель 1: нормализация без idf

# %%
scores = {}

# %%
tf_idf = TfIdf(preprocess=morph_sentence, idf=False)

ranker = TfIdfRanker(tf_idf)
ranker.load_docs(docs)

# %%
qid = 0

ranks = ranker.print_serp(queries[qid], relevant_docs[qid], norm=True)
ranks = [(doc_id, int(i < 10)) for i, (doc_id, _) in enumerate(ranks)]
metrics = count_metrics(relevant_docs[qid], ranks)

print()
print(("Precision: {:>.10f}\n" + \
       "Recall:    {:>.10f}\n" + \
       "F-measure: {:>.10f}\n" + \
       "NDCG-10:   {:>.10f}").format(*metrics))

scores[(qid, False)] = metrics
# Out:
# QUERY: Лётчику понадобилось два десятка лет, чтобы повторно стать подполковником.
# [NORMALIZED]
# лётчик понадобиться два десятка год чтобы повторно стать подполковник
#
#
# POS:   1
# DOCID: 1079
# RANK:  0.2738612788
#
# [o] С 2001 года работает в Гарвардском университете, спустя три года стал его профессором.
#
# [NORMALIZED]
# 2001 с год работать в гарвардский университет спустя три год стать он профессор
# ================================================================================
# POS:   2
# DOCID: 180
# RANK:  0.2738612788
#
# [*] 11 сентября 1940 года получил звание подполковника, а 21 февраля 1945 года — полковника.
#
# [NORMALIZED]
# 11 1940 21 1945 сентябрь год получить звание подполковник а февраль год полковник
# ================================================================================
# POS:   3
# DOCID: 398
# RANK:  0.2500000000
#
# [o] В 1888 году весь Бруней стал британским протекторатом.
#
# [NORMALIZED]
# 1888 в год весь бруней стать британский протекторат
# ================================================================================
# POS:   4
# DOCID: 528
# RANK:  0.2433321317
#
# [o] С 1993 г. с периодичностью раз в два года проводятся национальные спартакиады (Pesta Sukan Kebangsaan).
#
# [NORMALIZED]
# 1993 с год с периодичность раз в два год проводиться национальный спартакиада pesta sukan kebangsaan
# ================================================================================
# POS:   5
# DOCID: 170
# RANK:  0.2371708245
#
# [o] 24 ноября 1921 года назначен заведующим аэродромом отряда, а 20 мая 1922 года вновь получил должность военного лётчика.
#
# [NORMALIZED]
# 24 1921 20 1922 ноябрь год назначить заведовать аэродром отряд а май год вновь получить должность военный лётчик
# ================================================================================
# POS:   6
# DOCID: 121
# RANK:  0.2357022604
#
# [o] ↑ Папа римский Павел VI станет святым в 2018 году
#
# [NORMALIZED]
# 2018 папа римский павел vi стать святой в год
# ================================================================================
# POS:   7
# DOCID: 59
# RANK:  0.2357022604
#
# [o] Это требование стало применяться с 21 ноября 1970 года.
#
# [NORMALIZED]
# 21 1970 это требование стать применяться с ноябрь год
# ================================================================================
# POS:   8
# DOCID: 3
# RANK:  0.2236067977
#
# [o] 21 июня 1963 года — 6 августа 1978 года
#
# [NORMALIZED]
# 21 1963 6 1978 июнь год август год
# ================================================================================
# POS:   9
# DOCID: 79
# RANK:  0.2211629342
#
# [o] Он стал первым Римским понтификом с IX века, посетившим александрийского (в 1973 году) и константинопольского (в 1964 году) патриархов.
#
# [NORMALIZED]
# 1973 1964 он стать один римский понтифик с ix век посетить александрийский в год и константинопольский в год патриарх
# ================================================================================
# POS:   10
# DOCID: 2224
# RANK:  0.2041241452
#
# [o] Скотт бросил школу через год после убийств в 1992 году.
#
# [NORMALIZED]
# 1992 скотт бросить школа через год после убийство в год
# ================================================================================
#
# Precision: 0.1000000000
# Recall:    0.2000000000
# F-measure: 0.1333333333
# NDCG-10:   0.2139862647

# %%
qid = 1

ranks = ranker.print_serp(queries[qid], relevant_docs[qid], norm=True)
ranks = [(doc_id, int(i < 10)) for i, (doc_id, _) in enumerate(ranks)]
metrics = count_metrics(relevant_docs[qid], ranks)

print()
print(("Precision: {:>.10f}\n" + \
       "Recall:    {:>.10f}\n" + \
       "F-measure: {:>.10f}\n" + \
       "NDCG-10:   {:>.10f}").format(*metrics))

scores[(qid, False)] = metrics
# Out:
# QUERY: Не вызвавший первоначально интереса экспертов «маленький рыжеволосый мальчик» (на илл.) выставлен на аукционе со стартовой ценой в миллион евро.
# [NORMALIZED]
# не вызвать первоначально интерес эксперт маленький рыжеволосый мальчик на илл выставить на аукцион с стартовый цена в миллион евро
#
#
# POS:   1
# DOCID: 2416
# RANK:  0.3712129349
#
# [*] Она оценивается от 3 до 5 млн евро (по другим данным, только в 1 млн евро [2]) — в три раза больше, чем картина «Святой Иероним», которая должна быть выставлена в апреле 2018 года на аукционе «Кристис» (1 млн долларов).
#
# [NORMALIZED]
# 3 5 1 2 2018 1 она оцениваться от до миллион евро по другой данные только в миллион евро в три раз большой чем картина святой иероним который должный быть выставить в апрель год на аукцион кристис миллион доллар
# ================================================================================
# POS:   2
# DOCID: 27
# RANK:  0.3211820274
#
# [o] Несмотря на то, что он не входил в коллегию кардиналов, в 1958 году он получил на конклаве несколько голосов.
#
# [NORMALIZED]
# 1958 несмотря на то что он не входить в коллегия кардинал в год он получить на конклав несколько голос
# ================================================================================
# POS:   3
# DOCID: 704
# RANK:  0.3090575500
#
# [o] С другой стороны, Бор настаивал на принципиально недетерминированном (статистическом) характере квантовых явлений и на неустранимости эффекта влияния измерения на само состояние.
#
# [NORMALIZED]
# с другой сторона бора настаивать на принципиально недетерминированный статистический характер квантовый явление и на неустранимость эффект влияние измерение на сам состояние
# ================================================================================
# POS:   4
# DOCID: 1347
# RANK:  0.3077935056
#
# [o] Зрители зачастую падали на представлениях в обморок, и на такие случаи Метеньер держал в штате врача.
#
# [NORMALIZED]
# зритель зачастую падать на представление в обморок и на такой случай метеньер держать в штат врач
# ================================================================================
# POS:   5
# DOCID: 2078
# RANK:  0.3058876452
#
# [o] В этой статье не хватает ссылок на источники информации.
#
# [NORMALIZED]
# в этот статья не хватать ссылка на источник информация
# ================================================================================
# POS:   6
# DOCID: 461
# RANK:  0.3058876452
#
# [o] В этом разделе не хватает ссылок на источники информации.
#
# [NORMALIZED]
# в это раздел не хватать ссылка на источник информация
# ================================================================================
# POS:   7
# DOCID: 46
# RANK:  0.3034884893
#
# [o] В 1970 году в международном аэропорту Манилы на него было совершено покушение: художник-сюрреалист Бенхамин Мендоса-и-Амор Флорес бросился на папу с кинжалом.
#
# [NORMALIZED]
# 1970 в год в международный аэропорт манила на он быть совершить покушение художник сюрреалист бенхамин мендоса и амор флорес броситься на папа с кинжал
# ================================================================================
# POS:   8
# DOCID: 2265
# RANK:  0.3021797791
#
# [o] Эта версия настаивает на существовании двух неизвестных мужчин, которые вошли в магазин непосредственно перед закрытием, и указывает на конкретные доказательства их присутствия в помещении: невскрытая банка с колой со стоящей рядом ёмкостью для льда и заслуживающие доверия свидетельства двух ночных клиентов [7], стулья за одним столиком не были подняты, держатель салфеток на нём был пуст (в отличие от всех других столиков).
#
# [NORMALIZED]
# 7 этот версия настаивать на существование два неизвестный мужчина который войти в магазин непосредственно перед закрытие и указывать на конкретный доказательство они присутствие в помещение невскрытый банка с кола с стоящий ряд ёмкость для лёд и заслуживать доверие свидетельство два ночное клиент стул за один столик не быть поднять держатель салфетка на он быть пустой в отличие от весь другой столик
# ================================================================================
# POS:   9
# DOCID: 299
# RANK:  0.2809757435
#
# [o] Похоронен на Новодевичьем кладбище в Москве.
#
# [NORMALIZED]
# похоронный на новодевичий кладбище в москва
# ================================================================================
# POS:   10
# DOCID: 319
# RANK:  0.2809757435
#
# [o] Территория 22 (с песней «На таран»);
#
# [NORMALIZED]
# 22 территория с песня на таран
# ================================================================================
#
# Precision: 0.1000000000
# Recall:    0.2000000000
# F-measure: 0.1333333333
# NDCG-10:   0.3937481556

# %%
qid = 2

ranks = ranker.print_serp(queries[qid], relevant_docs[qid], norm=True)
ranks = [(doc_id, int(i < 10)) for i, (doc_id, _) in enumerate(ranks)]
metrics = count_metrics(relevant_docs[qid], ranks)

print()
print(("Precision: {:>.10f}\n" + \
       "Recall:    {:>.10f}\n" + \
       "F-measure: {:>.10f}\n" + \
       "NDCG-10:   {:>.10f}").format(*metrics))

scores[(qid, False)] = metrics
# Out:
# QUERY: Американский фотограф, известный съёмками высшего общества, был также личным фотографом знаменитого мафиозо.
# [NORMALIZED]
# американский фотограф известный съёмка высокий общество быть также личный фотограф знаменитый мафиозо
#
#
# POS:   1
# DOCID: 2557
# RANK:  0.3962969620
#
# [*] Джордж Аллен «Слим» Ааронс (29 октября 1916 — 30 мая 2006) — американский фотограф, известный съемками «красивой жизни» высшего общества, светских персон, кинозвёзд и прочих знаменитостей.
#
# [NORMALIZED]
# 29 1916 30 2006 джордж аллен слить ааронс октябрь май американский фотограф известный съёмка красивый жизнь высокий общество светский персона кинозвезда и прочий знаменитость
# ================================================================================
# POS:   2
# DOCID: 1161
# RANK:  0.3698001308
#
# [*] Лаки Лучано был любимой моделью американского фотографа Слима Ааронса.
#
# [NORMALIZED]
# лак лучано быть любимый модель американский фотограф слима ааронс
# ================================================================================
# POS:   3
# DOCID: 48
# RANK:  0.2264554068
#
# [o] Фотография Павла VI, фотограф Лотар Воллех
#
# [NORMALIZED]
# фотография павел vi фотограф лотар воллех
# ================================================================================
# POS:   4
# DOCID: 2691
# RANK:  0.1849000654
#
# [o] Наивысшая точность измерений была достигнута в начале 1970-х.
#
# [NORMALIZED]
# 1970 высокий точность измерение быть достигнуть в начало х
# ================================================================================
# POS:   5
# DOCID: 2180
# RANK:  0.1784103100
#
# [o] Это был Морис Эрл Пирс (англ. Maurice Earl Pierce (1975—2010), полиция тогда была убеждена, что он был вдохновителем преступления, но у них не было доказательств, подтверждающих это. Револьвер 22 калибра, который у него был найден, по результатам баллистической экспертизы, не был оружием, использованным в йогурт-кафе [3] [18]).
#
# [NORMALIZED]
# 1975 2010 22 3 18 это быть морис эрл пирс англ maurice earl pierce полиция тогда быть убедить что он быть вдохновитель преступление но у они не быть доказательство подтверждать это револьвер калибр который у он быть найти по результат баллистический экспертиза не быть оружие использовать в йогурт кафе
# ================================================================================
# POS:   6
# DOCID: 901
# RANK:  0.1754116039
#
# [o] Символ бифотона в статье на сайте Американского физического общества [73]
#
# [NORMALIZED]
# 73 символ бифотон в статья на сайт американский физический общество
# ================================================================================
# POS:   7
# DOCID: 2472
# RANK:  0.1698415551
#
# [o] На посту Главного раввина Израиля был известен усилиями по налаживанию диалога между еврейскими этническими общинами, а также религиозными и светскими гражданами Израиля.
#
# [NORMALIZED]
# на пост главный раввин израиль быть известный усилие по налаживание диалог между еврейский этнический община а также религиозный и светский гражданин израиль
# ================================================================================
# POS:   8
# DOCID: 2222
# RANK:  0.1672484020
#
# [o] Он был женат, у него была дочь.
#
# [NORMALIZED]
# он быть женатый у он быть дочь
# ================================================================================
# POS:   9
# DOCID: 2138
# RANK:  0.1664100589
#
# [o] Элиза также имела склонность к заботе о животных, в разное время у неё дома были раки, белые крысы, последним её увлечением была свинья.
#
# [NORMALIZED]
# элиза также иметь склонность к забота о животное в разный время у она дом быть рак белые крыса последний её увлечение быть свинья
# ================================================================================
# POS:   10
# DOCID: 1746
# RANK:  0.1601281538
#
# [o] Были предприняты также меры по защите Будапешта на случай «возможного внешнего нападения».
#
# [NORMALIZED]
# быть предпринять также мера по защита будапешт на случай возможный внешний нападение
# ================================================================================
#
# Precision: 0.2000000000
# Recall:    0.5000000000
# F-measure: 0.2857142857
# NDCG-10:   0.5606626602

# %% [markdown]
# ### Модель 2: нормализация c idf

# %%
tf_idf = TfIdf(preprocess=morph_sentence, idf=True)

ranker = TfIdfRanker(tf_idf)
ranker.load_docs(docs)

# %%
qid = 0

ranks = ranker.print_serp(queries[qid], relevant_docs[qid], norm=True)
ranks = [(doc_id, int(i < 10)) for i, (doc_id, _) in enumerate(ranks)]
metrics = count_metrics(relevant_docs[qid], ranks)

print()
print(("Precision: {:>.10f}\n" + \
       "Recall:    {:>.10f}\n" + \
       "F-measure: {:>.10f}\n" + \
       "NDCG-10:   {:>.10f}").format(*metrics))

scores[(qid, True)] = metrics
# Out:
# QUERY: Лётчику понадобилось два десятка лет, чтобы повторно стать подполковником.
# [NORMALIZED]
# лётчик понадобиться два десятка год чтобы повторно стать подполковник
#
#
# POS:   1
# DOCID: 2190
# RANK:  0.2214248002
#
# [o] Он был вынужден повторно учиться в 10 классе.
#
# [NORMALIZED]
# 10 он быть вынужденный повторно учиться в класс
# ================================================================================
# POS:   2
# DOCID: 2213
# RANK:  0.1762893825
#
# [o] Полицейские повторно допросили Скотта по телефону, но он отрицал причастность.
#
# [NORMALIZED]
# полицейский повторно допросить скотт по телефон но он отрицать причастность
# ================================================================================
# POS:   3
# DOCID: 180
# RANK:  0.1620625084
#
# [*] 11 сентября 1940 года получил звание подполковника, а 21 февраля 1945 года — полковника.
#
# [NORMALIZED]
# 11 1940 21 1945 сентябрь год получить звание подполковник а февраль год полковник
# ================================================================================
# POS:   4
# DOCID: 149
# RANK:  0.1495289028
#
# [*] Подполковник Российской императорской армии (1917), участник Первой мировой войны.
#
# [NORMALIZED]
# 1917 подполковник российский императорский армия участник один мировой война
# ================================================================================
# POS:   5
# DOCID: 146
# RANK:  0.1454706200
#
# [*] подполковник Российской императорской армии полковник Красной армии
#
# [NORMALIZED]
# подполковник российский императорский армия полковник красный армия
# ================================================================================
# POS:   6
# DOCID: 1673
# RANK:  0.1250868289
#
# [o] 29 октября Миклош Хорти, бывший правителем (регентом) Королевства Венгрия до 1944 года и живущий в Португалии, обратился к главам государств США, Великобритании и ФРГ с просьбой оказать помощь венгерской «революции» и, если понадобится, вмешаться военными средствами в интересах её победы [24] [неавторитетный источник?].
#
# [NORMALIZED]
# 29 1944 24 октябрь миклош хортить бывший правитель регент королевство венгрия до год и жить в португалия обратиться к глава государство сша великобритания и фрг с просьба оказать помощь венгерский революция и если понадобиться вмешаться военный средство в интерес её победа неавторитетный источник
# ================================================================================
# POS:   7
# DOCID: 173
# RANK:  0.1209465426
#
# [o] 1 марта 1927 года был назначен помощником Высшей школы воздушного боя Военно-воздушных сил Красной армии по технической части, а 28 февраля 1929 года занял должность преподавателя в 3-й военной школе лётчиков и лётчиков-наблюдателей им. К. Е. Ворошилова.
#
# [NORMALIZED]
# 1 1927 28 1929 3 март год быть назначить помощник высокий школа воздушный бой военный воздушный сила красный армия по технический часть а февраль год занять должность преподаватель в й военный школа лётчик и лётчик наблюдатель имя к е ворошилов
# ================================================================================
# POS:   8
# DOCID: 318
# RANK:  0.1204926472
#
# [o] Про лётчика Талалихина исполняли песни группы:
#
# [NORMALIZED]
# про лётчик талалихин исполнять песнь группа
# ================================================================================
# POS:   9
# DOCID: 336
# RANK:  0.1029498832
#
# [o] Мемориал Виктора Талалихина — лётчика, Героя Советского Союза, первым совершившего ночной таран
#
# [NORMALIZED]
# мемориал виктор талалихин лётчик герой советский союз один совершить ночной таран
# ================================================================================
# POS:   10
# DOCID: 291
# RANK:  0.1023634442
#
# [o] В настоящее время данные о воздушных победах летчика не подтверждаются архивными источниками [3].
#
# [NORMALIZED]
# 3 в настоящее время дать о воздушный победа лётчик не подтверждаться архивный источник
# ================================================================================
#
# Precision: 0.3000000000
# Recall:    0.6000000000
# F-measure: 0.4000000000
# NDCG-10:   0.4468535300

# %%
qid = 1

ranks = ranker.print_serp(queries[qid], relevant_docs[qid], norm=True)
ranks = [(doc_id, int(i < 10)) for i, (doc_id, _) in enumerate(ranks)]
metrics = count_metrics(relevant_docs[qid], ranks)

print()
print(("Precision: {:>.10f}\n" + \
       "Recall:    {:>.10f}\n" + \
       "F-measure: {:>.10f}\n" + \
       "NDCG-10:   {:>.10f}").format(*metrics))

scores[(qid, True)] = metrics
# Out:
# QUERY: Не вызвавший первоначально интереса экспертов «маленький рыжеволосый мальчик» (на илл.) выставлен на аукционе со стартовой ценой в миллион евро.
# [NORMALIZED]
# не вызвать первоначально интерес эксперт маленький рыжеволосый мальчик на илл выставить на аукцион с стартовый цена в миллион евро
#
#
# POS:   1
# DOCID: 2416
# RANK:  0.3828105146
#
# [*] Она оценивается от 3 до 5 млн евро (по другим данным, только в 1 млн евро [2]) — в три раза больше, чем картина «Святой Иероним», которая должна быть выставлена в апреле 2018 года на аукционе «Кристис» (1 млн долларов).
#
# [NORMALIZED]
# 3 5 1 2 2018 1 она оцениваться от до миллион евро по другой данные только в миллион евро в три раз большой чем картина святой иероним который должный быть выставить в апрель год на аукцион кристис миллион доллар
# ================================================================================
# POS:   2
# DOCID: 2389
# RANK:  0.2762826438
#
# [*] Владелица увидела Руйяков по телевидению; в разговоре по телефону она называла картину «Маленький рыжеволосый мальчик».
#
# [NORMALIZED]
# владелица увидеть руйяк по телевидение в разговор по телефон она называть картина маленький рыжеволосый мальчик
# ================================================================================
# POS:   3
# DOCID: 2425
# RANK:  0.2616635053
#
# [o] , самая высокая цена, полученная на аукционе за работы братьев Ленен, долгое время составляла всего 25 тысяч евро (2002 год) [8].
#
# [NORMALIZED]
# 25 2002 8 самый высокий цена получить на аукцион за работа брат ленный долгий время составлять всего тысяча евро год
# ================================================================================
# POS:   4
# DOCID: 2426
# RANK:  0.1824578226
#
# [o] Лувр в 2009 году приобрёл картину «Отречение святого Петра» этих художников за 11,5 млн евро.
#
# [NORMALIZED]
# 2009 11 5 лувр в год приобрести картина отречение святой петра этот художник за миллион евро
# ================================================================================
# POS:   5
# DOCID: 2167
# RANK:  0.1756472793
#
# [o] Эксперты утверждали, что тело Дженнифер Харбисон первоначально лежало на двух других телах, однако было найдено рядом.
#
# [NORMALIZED]
# эксперт утверждать что тело дженнифер харбисон первоначально лежалый на два другой тело однако быть найти ряд
# ================================================================================
# POS:   6
# DOCID: 2415
# RANK:  0.1200199062
#
# [o] Картина будет представлена на аукционе 10 июня 2018 года в замке Артини (фр.) русск.
#
# [NORMALIZED]
# 10 2018 картина быть представить на аукцион июнь год в замок артиня фр русск
# ================================================================================
# POS:   7
# DOCID: 2381
# RANK:  0.1067894118
#
# [o] Иисус (по оценке экспертов, ему можно дать возраст от 6 до 8 лет) стоит на коленях, скрестив руки на груди.
#
# [NORMALIZED]
# 6 8 иисус по оценка эксперт он можно дать возраст от до год стоить на колено скрестить рука на грудь
# ================================================================================
# POS:   8
# DOCID: 1544
# RANK:  0.1053099971
#
# [o] На миллион жителей Венгрии АВХ завела досье — более чем на 10 % всего населения, включая стариков и детей.
#
# [NORMALIZED]
# 10 на миллион житель венгрия авх завести досье более чем на всего население включая старик и ребёнок
# ================================================================================
# POS:   9
# DOCID: 1555
# RANK:  0.1043260425
#
# [o] Капиталовложения были направлены на развитие лёгкой и пищевой промышленности, было ослаблено давление на сельское хозяйство, снижены цены на продукты и тарифы для населения [12].
#
# [NORMALIZED]
# 12 капиталовложение быть направить на развитие лёгкий и пищевой промышленность быть ослабить давление на сельский хозяйство снизить цена на продукт и тариф для население
# ================================================================================
# POS:   10
# DOCID: 2423
# RANK:  0.0998032818
#
# [o] Однако на рынке картин к настоящему времени представлено достаточно мало их работ, а цены сравнительно невысоки.
#
# [NORMALIZED]
# однако на рынок картина к настоящий время представить достаточно мало они работа а цена сравнительно невысокий
# ================================================================================
#
# Precision: 0.2000000000
# Recall:    0.4000000000
# F-measure: 0.2666666667
# NDCG-10:   0.6421755823

# %%
qid = 2

ranks = ranker.print_serp(queries[qid], relevant_docs[qid], norm=True)
ranks = [(doc_id, int(i < 10)) for i, (doc_id, _) in enumerate(ranks)]
metrics = count_metrics(relevant_docs[qid], ranks)

print()
print(("Precision: {:>.10f}\n" + \
       "Recall:    {:>.10f}\n" + \
       "F-measure: {:>.10f}\n" + \
       "NDCG-10:   {:>.10f}").format(*metrics))

scores[(qid, True)] = metrics
# Out:
# QUERY: Американский фотограф, известный съёмками высшего общества, был также личным фотографом знаменитого мафиозо.
# [NORMALIZED]
# американский фотограф известный съёмка высокий общество быть также личный фотограф знаменитый мафиозо
#
#
# POS:   1
# DOCID: 2557
# RANK:  0.3885780952
#
# [*] Джордж Аллен «Слим» Ааронс (29 октября 1916 — 30 мая 2006) — американский фотограф, известный съемками «красивой жизни» высшего общества, светских персон, кинозвёзд и прочих знаменитостей.
#
# [NORMALIZED]
# 29 1916 30 2006 джордж аллен слить ааронс октябрь май американский фотограф известный съёмка красивый жизнь высокий общество светский персона кинозвезда и прочий знаменитость
# ================================================================================
# POS:   2
# DOCID: 1161
# RANK:  0.2889444851
#
# [*] Лаки Лучано был любимой моделью американского фотографа Слима Ааронса.
#
# [NORMALIZED]
# лак лучано быть любимый модель американский фотограф слима ааронс
# ================================================================================
# POS:   3
# DOCID: 48
# RANK:  0.2360169884
#
# [o] Фотография Павла VI, фотограф Лотар Воллех
#
# [NORMALIZED]
# фотография павел vi фотограф лотар воллех
# ================================================================================
# POS:   4
# DOCID: 901
# RANK:  0.2043022609
#
# [o] Символ бифотона в статье на сайте Американского физического общества [73]
#
# [NORMALIZED]
# 73 символ бифотон в статья на сайт американский физический общество
# ================================================================================
# POS:   5
# DOCID: 2616
# RANK:  0.1614282880
#
# [o] Категории : Персоналии по алфавиту Родившиеся 29 октября Родившиеся в 1916 году Родившиеся в Нью-Йорке Умершие 30 мая Умершие в 2006 году Умершие в Монтрозе (Нью-Йорк) Награждённые медалью «Пурпурное сердце» Фотографы США Скрытые категории: Страницы, использующие волшебные ссылки ISBN Википедия:Статьи с переопределением значения из Викиданных Википедия:Статьи без изображений (тип: человек; род занятий: фотограф)
#
# [NORMALIZED]
# 29 1916 30 2006 категория персоналия по алфавит родиться октябрь родиться в год родиться в нью йорк умерший май умерший в год умерший в монтроза нью йорк наградить медаль пурпурный сердце фотограф сша скрытый категория страница использовать волшебный ссылка isbn википедия статья с переопределение значение из викидать википедия статья без изображение тип человек род занятие фотограф
# ================================================================================
# POS:   6
# DOCID: 2584
# RANK:  0.1541552209
#
# [o] В 1997 году Марк Гетти, один из основателей Getty Images, целиком выкупил архив фотографа.
#
# [NORMALIZED]
# 1997 в год марк гетти один из основатель getty image целиком выкупить архив фотограф
# ================================================================================
# POS:   7
# DOCID: 325
# RANK:  0.1482616196
#
# [o] ↑ Знаменитый ас на «незнаменитой» войне
#
# [NORMALIZED]
# знаменитый ас на незнаменитый война
# ================================================================================
# POS:   8
# DOCID: 2561
# RANK:  0.1297722328
#
# [o] В возрасте 18 лет он вступил в армию США, фотографировал для военной академии Вест-Пойнт и позже в качестве военного фотографа участвовал во Второй мировой войне (награжден медалью «Пурпурное сердце»).
#
# [NORMALIZED]
# 18 в возраст год он вступить в армия сша фотографировать для военный академия вест пойнт и поздний в качество военный фотограф участвовать в два мировой война наградить медаль пурпурный сердце
# ================================================================================
# POS:   9
# DOCID: 2556
# RANK:  0.1154664881
#
# [o] Слим Ааронс на съемках фильма «Мистер Робертс» (Гавайи, 1954)
#
# [NORMALIZED]
# 1954 слить ааронс на съёмка фильм мистер робертс гавайи
# ================================================================================
# POS:   10
# DOCID: 1068
# RANK:  0.1129333360
#
# [o] Институт квантовой оптики общества Макса Планка Гарвардский университет
#
# [NORMALIZED]
# институт квантовый оптика общество макс планка гарвардский университет
# ================================================================================
#
# Precision: 0.2000000000
# Recall:    0.5000000000
# F-measure: 0.2857142857
# NDCG-10:   0.5606626602

# %% [markdown]
# ### Модель 3: языковая модель

# %%
ranker = LangModelRanker(lambda_=0.8)
ranker.load_docs(docs)

# %%
qid = 0

ranks = ranker.print_serp(queries[qid], relevant_docs[qid], norm=True, probs=True)
ranks = [(doc_id, int(i < 10)) for i, (doc_id, _) in enumerate(ranks)]
metrics = count_metrics(relevant_docs[qid], ranks)

print()
print(("Precision: {:>.10f}\n" + \
       "Recall:    {:>.10f}\n" + \
       "F-measure: {:>.10f}\n" + \
       "NDCG-10:   {:>.10f}").format(*metrics))

scores[(qid, 2)] = metrics
# Out:
# QUERY: Лётчику понадобилось два десятка лет, чтобы повторно стать подполковником.
# [NORMALIZED]
# лётчик понадобиться два десятка год чтобы повторно стать подполковник
#
# P(год|model) = 0.01344
# P(два|model) = 0.00161
# P(стать|model) = 0.00165
# P(подполковник|model) = 0.00014
# P(лётчик|model) = 0.00037
# P(чтобы|model) = 0.00065
# P(понадобиться|model) = 0.00001
# P(повторно|model) = 0.00009
#
# POS:   1
# DOCID: 218
# RANK:  1.33530522549381e-27
#
# [o] Категории : Родившиеся 27 ноября Родившиеся в 1890 году Персоналии по алфавиту Родившиеся в Гродненской губернии Кавалеры ордена Ленина Кавалеры ордена Красного Знамени Награждённые медалью «XX лет Рабоче-Крестьянской Красной Армии» Награждённые медалью «За победу над Германией в Великой Отечественной войне 1941—1945 гг.» Кавалеры ордена Святого Георгия IV класса Кавалеры ордена Святой Анны 2 степени Кавалеры ордена Святой Анны 3 степени Кавалеры ордена Святого Станислава 2 степени с мечами Кавалеры ордена Святого Станислава 3 степени Кавалеры Георгиевского оружия Подполковники (Российская империя) Полковники (СССР) Российские лётчики Первой мировой войны Участники Гражданской войны в России Военные лётчики СССР Члены КПСС Выпускники Либавского реального училища Скрытые категории: Страницы, использующие волшебные ссылки ISBN Википедия:Статьи с переопределением значения из Викиданных Википедия:Статьи с ручной викификацией дат в карточке Википедия:Добротные статьи:Лётчики и воздушные стрелки Википедия:Добротные статьи по алфавиту
#
# [NORMALIZED]
# 27 1890 1941 1945 2 3 2 3 категория родиться ноябрь родиться в год персоналия по алфавит родиться в гродненский губерния кавалер орден ленин кавалер орден красный знамя наградить медаль xx год рабочий крестьянский красный армия наградить медаль за победа над германия в великий отечественный война год кавалер орден святой георгий iv класс кавалер орден святой анна степень кавалер орден святой анна степень кавалер орден святой станислав степень с меч кавалер орден святой станислав степень кавалер георгиевский оружие подполковник российский империя полковник ссср российский лётчик один мировой война участник гражданский война в россия военный лётчик ссср член кпсс выпускник либавский реальный училище скрытый категория страница использовать волшебный ссылка isbn википедия статья с переопределение значение из викидать википедия статья с ручной викификация дата в карточка википедия добротный статья лётчик и воздушный стрелка википедия добротный статья по алфавит
# ================================================================================
# POS:   2
# DOCID: 180
# RANK:  3.5690918415111797e-28
#
# [*] 11 сентября 1940 года получил звание подполковника, а 21 февраля 1945 года — полковника.
#
# [NORMALIZED]
# 11 1940 21 1945 сентябрь год получить звание подполковник а февраль год полковник
# ================================================================================
# POS:   3
# DOCID: 1673
# RANK:  2.0773920567222566e-28
#
# [o] 29 октября Миклош Хорти, бывший правителем (регентом) Королевства Венгрия до 1944 года и живущий в Португалии, обратился к главам государств США, Великобритании и ФРГ с просьбой оказать помощь венгерской «революции» и, если понадобится, вмешаться военными средствами в интересах её победы [24] [неавторитетный источник?].
#
# [NORMALIZED]
# 29 1944 24 октябрь миклош хортить бывший правитель регент королевство венгрия до год и жить в португалия обратиться к глава государство сша великобритания и фрг с просьба оказать помощь венгерский революция и если понадобиться вмешаться военный средство в интерес её победа неавторитетный источник
# ================================================================================
# POS:   4
# DOCID: 2697
# RANK:  1.2176949717462082e-28
#
# [o] Как крайний пример замедления света, можно сказать, что двум независимым группам физиков удалось полностью «остановить» свет, пропуская его через конденсат Бозе-Эйнштейна на основе рубидия, [8] Тем не менее слово «остановить» в этих экспериментах относится только к свету, хранящемуся в возбужденных состояниях атомов, а затем повторно излучаемому в произвольное более позднее время, как вынужденное вторым лазерным импульсом излучение.
#
# [NORMALIZED]
# 8 как крайний пример замедление свет можно сказать что два независимый группа физик удаться полностью остановить свет пропускать он через конденсат боз эйнштейн на основа рубидий тем не менее слово остановить в этот эксперимент относиться только к света храниться в возбудить состояние атом а затем повторно излучать в произвольный более поздний время как вынужденный второе лазерный импульс излучение
# ================================================================================
# POS:   5
# DOCID: 165
# RANK:  1.0665479381675524e-28
#
# [*] 19 мая 1916 года Николай Мульков был произведён в чин штабс-капитана, 17 августа 1917 года в капитаны, а на следующий день — в подполковники.
#
# [NORMALIZED]
# 19 1916 17 1917 май год николай мулёк быть произвести в чин штабс капитан август год в капитан а на следующий день в подполковник
# ================================================================================
# POS:   6
# DOCID: 2690
# RANK:  7.664303680809707e-29
#
# [o] В ходе этих измерений А. Майкельсон измерял время, требовавшееся свету, чтобы пройти расстояние между вершинами двух гор, равное 35,4 км (точнее, 35 373,21 м) [6].
#
# [NORMALIZED]
# 35 4 35 373 21 6 в ход этот измерение а майкельсон измерять время требоваться света чтобы пройти расстояние между вершина два гора равный километр точнее метр
# ================================================================================
# POS:   7
# DOCID: 170
# RANK:  7.402844019498498e-29
#
# [o] 24 ноября 1921 года назначен заведующим аэродромом отряда, а 20 мая 1922 года вновь получил должность военного лётчика.
#
# [NORMALIZED]
# 24 1921 20 1922 ноябрь год назначить заведовать аэродром отряд а май год вновь получить должность военный лётчик
# ================================================================================
# POS:   8
# DOCID: 398
# RANK:  4.159366163053818e-29
#
# [o] В 1888 году весь Бруней стал британским протекторатом.
#
# [NORMALIZED]
# 1888 в год весь бруней стать британский протекторат
# ================================================================================
# POS:   9
# DOCID: 289
# RANK:  3.4307324661159496e-29
#
# [o] В 1938 году окончил Борисоглебскую военную авиационную школу лётчиков в городе Борисоглебск Воронежской области и получил звание младшего лейтенанта.
#
# [NORMALIZED]
# 1938 в год окончить борисоглебский военный авиационный школа лётчик в город борисоглебск воронежский область и получить звание младший лейтенант
# ================================================================================
# POS:   10
# DOCID: 59
# RANK:  3.2985268209369935e-29
#
# [o] Это требование стало применяться с 21 ноября 1970 года.
#
# [NORMALIZED]
# 21 1970 это требование стать применяться с ноябрь год
# ================================================================================
#
# Precision: 0.2000000000
# Recall:    0.4000000000
# F-measure: 0.2666666667
# NDCG-10:   0.3451913422

# %%
qid = 1

ranks = ranker.print_serp(queries[qid], relevant_docs[qid], norm=True, probs=True)
ranks = [(doc_id, int(i < 10)) for i, (doc_id, _) in enumerate(ranks)]
metrics = count_metrics(relevant_docs[qid], ranks)

print()
print(("Precision: {:>.10f}\n" + \
       "Recall:    {:>.10f}\n" + \
       "F-measure: {:>.10f}\n" + \
       "NDCG-10:   {:>.10f}").format(*metrics))

scores[(qid, 2)] = metrics
# Out:
# QUERY: Не вызвавший первоначально интереса экспертов «маленький рыжеволосый мальчик» (на илл.) выставлен на аукционе со стартовой ценой в миллион евро.
# [NORMALIZED]
# не вызвать первоначально интерес эксперт маленький рыжеволосый мальчик на илл выставить на аукцион с стартовый цена в миллион евро
#
# P(в|model) = 0.03517
# P(с|model) = 0.01289
# P(на|model) = 0.01069
# P(не|model) = 0.00469
# P(вызвать|model) = 0.00014
# P(миллион|model) = 0.00013
# P(маленький|model) = 0.00018
# P(интерес|model) = 0.00018
# P(первоначально|model) = 0.00013
# P(цена|model) = 0.00011
# P(эксперт|model) = 0.00013
# P(аукцион|model) = 0.00012
# P(мальчик|model) = 0.00005
# P(выставить|model) = 0.00003
# P(рыжеволосый|model) = 0.00002
# P(евро|model) = 0.00010
#
# POS:   1
# DOCID: 2416
# RANK:  9.575889031255278e-53
#
# [*] Она оценивается от 3 до 5 млн евро (по другим данным, только в 1 млн евро [2]) — в три раза больше, чем картина «Святой Иероним», которая должна быть выставлена в апреле 2018 года на аукционе «Кристис» (1 млн долларов).
#
# [NORMALIZED]
# 3 5 1 2 2018 1 она оцениваться от до миллион евро по другой данные только в миллион евро в три раз большой чем картина святой иероним который должный быть выставить в апрель год на аукцион кристис миллион доллар
# ================================================================================
# POS:   2
# DOCID: 2389
# RANK:  4.941402029934096e-56
#
# [*] Владелица увидела Руйяков по телевидению; в разговоре по телефону она называла картину «Маленький рыжеволосый мальчик».
#
# [NORMALIZED]
# владелица увидеть руйяк по телевидение в разговор по телефон она называть картина маленький рыжеволосый мальчик
# ================================================================================
# POS:   3
# DOCID: 2425
# RANK:  6.921491204284117e-57
#
# [o] , самая высокая цена, полученная на аукционе за работы братьев Ленен, долгое время составляла всего 25 тысяч евро (2002 год) [8].
#
# [NORMALIZED]
# 25 2002 8 самый высокий цена получить на аукцион за работа брат ленный долгий время составлять всего тысяча евро год
# ================================================================================
# POS:   4
# DOCID: 2427
# RANK:  9.577243589480206e-60
#
# [o] Тем не менее только что открытая картина находится в небольшой частной коллекции, её предыстория неизвестна и вряд ли поддаётся изучению, в то время как «Отречение святого Петра» значительно больше размером и была, вероятно, написана для самого кардинала Джулио Мазарини, к тому же желание крупнейшего государственного музея Франции приобрести картину «Отречение святого Петра», о котором стало известно задолго до начала аукциона, вероятно, стимулировало резкий рост цен на неё на торгах [1].
#
# [NORMALIZED]
# 1 тем не менее только что открытый картина находиться в небольшой частный коллекция её предыстория неизвестный и вряд ли поддаваться изучение в то время как отречение святой петра значительно большой размер и быть вероятно написать для самый кардинал джулио мазариня к тот же желание крупный государственный музей франция приобрести картина отречение святой петра о который стать известно задолго до начало аукцион вероятно стимулировать резкий рост цена на она на торг
# ================================================================================
# POS:   5
# DOCID: 2167
# RANK:  4.857682782195963e-60
#
# [o] Эксперты утверждали, что тело Дженнифер Харбисон первоначально лежало на двух других телах, однако было найдено рядом.
#
# [NORMALIZED]
# эксперт утверждать что тело дженнифер харбисон первоначально лежалый на два другой тело однако быть найти ряд
# ================================================================================
# POS:   6
# DOCID: 2426
# RANK:  2.118841389520718e-60
#
# [o] Лувр в 2009 году приобрёл картину «Отречение святого Петра» этих художников за 11,5 млн евро.
#
# [NORMALIZED]
# 2009 11 5 лувр в год приобрести картина отречение святой петра этот художник за миллион евро
# ================================================================================
# POS:   7
# DOCID: 1401
# RANK:  3.001572288637756e-61
#
# [o] Гиньоль — театр маленький, публика в нём большею частью иностранная, но претензии на литературность и художественность у Гран Гиньоля отнюдь не дутые.
#
# [NORMALIZED]
# гиньоль театр маленький публика в он больший частью иностранный но претензия на литературность и художественность у гран гиньоль отнюдь не дутый
# ================================================================================
# POS:   8
# DOCID: 1377
# RANK:  5.296953273737722e-62
#
# [o] Представление начиналось с комедий, первоначально настраивая публику на несерьёзный лад, после чего разворачивалась жуткая кровавая драма.
#
# [NORMALIZED]
# представление начинаться с комедия первоначально настраивать публика на несерьёзный лада после что разворачиваться жуткий кровавый драма
# ================================================================================
# POS:   9
# DOCID: 1900
# RANK:  4.531818433431991e-62
#
# [o] В письме содержалось указание коммунистам, работающим в органах государственной безопасности, «…зорко стоять на страже интересов нашего социалистического государства, быть бдительными к проискам враждебных элементов и, в соответствии с законами Советской власти, своевременно пресекать преступные действия».
#
# [NORMALIZED]
# в письмо содержаться указание коммунист работать в орган государственный безопасность зорко стоять на стража интерес наш социалистический государство быть бдительный к происки враждебный элемент и в соответствие с закон советский власть своевременно пресекать преступный действие
# ================================================================================
# POS:   10
# DOCID: 2390
# RANK:  3.979342576793686e-62
#
# [*] Она сообщила, что ряд парижских аукционистов, к которым она уже обращалась некоторое время назад, не заинтересовались картиной, ссылаясь на слабый интерес рынка к картинам на религиозный сюжет [6].
#
# [NORMALIZED]
# 6 она сообщить что ряд парижский аукционист к который она уже обращаться некоторый время назад не заинтересоваться картина ссылаться на слабый интерес рынок к картина на религиозный сюжет
# ================================================================================
#
# Precision: 0.3000000000
# Recall:    0.6000000000
# F-measure: 0.4000000000
# NDCG-10:   0.7559943246

# %%
qid = 2

ranks = ranker.print_serp(queries[qid], relevant_docs[qid], norm=True, probs=True)
ranks = [(doc_id, int(i < 10)) for i, (doc_id, _) in enumerate(ranks)]
metrics = count_metrics(relevant_docs[qid], ranks)

print()
print(("Precision: {:>.10f}\n" + \
       "Recall:    {:>.10f}\n" + \
       "F-measure: {:>.10f}\n" + \
       "NDCG-10:   {:>.10f}").format(*metrics))

scores[(qid, 2)] = metrics
# Out:
# QUERY: Американский фотограф, известный съёмками высшего общества, был также личным фотографом знаменитого мафиозо.
# [NORMALIZED]
# американский фотограф известный съёмка высокий общество быть также личный фотограф знаменитый мафиозо
#
# P(быть|model) = 0.00993
# P(американский|model) = 0.00038
# P(фотограф|model) = 0.00019
# P(известный|model) = 0.00059
# P(общество|model) = 0.00019
# P(также|model) = 0.00156
# P(высокий|model) = 0.00052
# P(съёмка|model) = 0.00013
# P(знаменитый|model) = 0.00011
# P(личный|model) = 0.00019
#
# POS:   1
# DOCID: 2557
# RANK:  7.529517013736699e-25
#
# [*] Джордж Аллен «Слим» Ааронс (29 октября 1916 — 30 мая 2006) — американский фотограф, известный съемками «красивой жизни» высшего общества, светских персон, кинозвёзд и прочих знаменитостей.
#
# [NORMALIZED]
# 29 1916 30 2006 джордж аллен слить ааронс октябрь май американский фотограф известный съёмка красивый жизнь высокий общество светский персона кинозвезда и прочий знаменитость
# ================================================================================
# POS:   2
# DOCID: 1161
# RANK:  2.485893136691512e-33
#
# [*] Лаки Лучано был любимой моделью американского фотографа Слима Ааронса.
#
# [NORMALIZED]
# лак лучано быть любимый модель американский фотограф слима ааронс
# ================================================================================
# POS:   3
# DOCID: 901
# RANK:  4.4735594432887654e-35
#
# [o] Символ бифотона в статье на сайте Американского физического общества [73]
#
# [NORMALIZED]
# 73 символ бифотон в статья на сайт американский физический общество
# ================================================================================
# POS:   4
# DOCID: 2472
# RANK:  1.4249443202540162e-35
#
# [o] На посту Главного раввина Израиля был известен усилиями по налаживанию диалога между еврейскими этническими общинами, а также религиозными и светскими гражданами Израиля.
#
# [NORMALIZED]
# на пост главный раввин израиль быть известный усилие по налаживание диалог между еврейский этнический община а также религиозный и светский гражданин израиль
# ================================================================================
# POS:   5
# DOCID: 1373
# RANK:  5.0257262251228574e-36
#
# [o] (1869 — 1942), который охотно сотрудничал с известным психологом Альфредом Бине [7] — знаменитая «Лекция в Сальпетриере» и т. д. Совместно Бине и де Лорд написали пять пьес, которые исследователи окрестили «медицинским театром».
#
# [NORMALIZED]
# 1869 1942 7 который охотно сотрудничать с известный психолог альфред биня знаменитый лекция в сальпетриер и том далее совместно биня и де лорд написать пять пьеса который исследователь окрестить медицинский театр
# ================================================================================
# POS:   6
# DOCID: 2691
# RANK:  7.926747563362397e-37
#
# [o] Наивысшая точность измерений была достигнута в начале 1970-х.
#
# [NORMALIZED]
# 1970 высокий точность измерение быть достигнуть в начало х
# ================================================================================
# POS:   7
# DOCID: 1764
# RANK:  4.990267532543773e-37
#
# [o] Перед началом операции до всего личного состава советских войск в Венгрии был доведён приказ № 1 Главнокомандующего Объединёнными вооружёнными силами.
#
# [NORMALIZED]
# 1 перед начало операция до всего личный состав советский войско в венгрия быть довести приказ главнокомандующий объединить вооружённый сила
# ================================================================================
# POS:   8
# DOCID: 2679
# RANK:  4.715010358146187e-37
#
# [o] Тем не менее, его размер не был известен в то время.
#
# [NORMALIZED]
# тем не менее он размер не быть известный в то время
# ================================================================================
# POS:   9
# DOCID: 1156
# RANK:  3.597172486938538e-37
#
# [o] В 1962 году был приглашён на съёмку документального фильма о мафии, но при встрече с режиссёром с ним случился инфаркт, и он умер по пути в больницу.
#
# [NORMALIZED]
# 1962 в год быть пригласить на съёмка документальный фильм о мафия но при встреча с режиссёр с он случиться инфаркт и он умереть по путь в больница
# ================================================================================
# POS:   10
# DOCID: 1355
# RANK:  1.7924848704945329e-37
#
# [o] Символично, что Рошгросс был известен как художник, изображавший различные кровавые и батальные сюжеты с академической тщательностью и детализацией.
#
# [NORMALIZED]
# символичный что рошгросс быть известный как художник изображать различный кровавый и батальный сюжет с академический тщательность и детализация
# ================================================================================
#
# Precision: 0.2000000000
# Recall:    0.5000000000
# F-measure: 0.2857142857
# NDCG-10:   0.5606626602

# %% [markdown]
# ## Сравнение моделей

# %%
for qid, _ in enumerate(queries):
    print(f"Metrics for QID: {qid+1}\n")
    print("           {:<12} {:<12} {:<12}".format("no IDF", "IDF", "LModel"))
    print("Precision: {:>.10f} {:>.10f} {:>.10f}".format(*(scores[(qid, i)][0] for i in range(3))))
    print("Recall:    {:>.10f} {:>.10f} {:>.10f}".format(*(scores[(qid, i)][1] for i in range(3))))
    print("F-measure: {:>.10f} {:>.10f} {:>.10f}".format(*(scores[(qid, i)][2] for i in range(3))))
    print("NDCG-10:   {:>.10f} {:>.10f} {:>.10f}".format(*(scores[(qid, i)][3] for i in range(3))))
    print("NDCG:      {:>.10f} {:>.10f} {:>.10f}".format(*(scores[(qid, i)][4] for i in range(3))))
    print("=" * 60 + '\n')
# Out:
# Metrics for QID: 1
#
#            no IDF       IDF          LModel
# Precision: 0.1000000000 0.3000000000 0.2000000000
# Recall:    0.2000000000 0.6000000000 0.4000000000
# F-measure: 0.1333333333 0.4000000000 0.2666666667
# NDCG-10:   0.2139862647 0.4468535300 0.3451913422
# NDCG:      0.4292651556 0.6227445764 0.5516950142
# ============================================================
#
# Metrics for QID: 2
#
#            no IDF       IDF          LModel
# Precision: 0.1000000000 0.2000000000 0.3000000000
# Recall:    0.2000000000 0.4000000000 0.6000000000
# F-measure: 0.1333333333 0.2666666667 0.4000000000
# NDCG-10:   0.3937481556 0.6421755823 0.7559943246
# NDCG:      0.5711782645 0.7827567770 0.7988582470
# ============================================================
#
# Metrics for QID: 3
#
#            no IDF       IDF          LModel
# Precision: 0.2000000000 0.2000000000 0.2000000000
# Recall:    0.5000000000 0.5000000000 0.5000000000
# F-measure: 0.2857142857 0.2857142857 0.2857142857
# NDCG-10:   0.5606626602 0.5606626602 0.5606626602
# NDCG:      0.6494015612 0.6681382680 0.6692960993
# ============================================================

# %%
print(f"Mean metrics for QIDs\n")
print("{:<10s} {:<12} {:<12} {:<12}".format("", "no IDF", "IDF", "LModel"))

for i, metric in enumerate(["Precision:", "Recall:", "F-measure:", "NDCG-10:", "NDCG:"]):
    score_0 = np.mean([scores[(qid, 0)][i] for qid in range(len(queries))])
    score_1 = np.mean([scores[(qid, 1)][i] for qid in range(len(queries))])
    score_2 = np.mean([scores[(qid, 2)][i] for qid in range(len(queries))])
    
    print("{:<10s} {:>.10f} {:>.10f} {:>.10f}".format(metric, score_0, score_1, score_2))
# Out:
# Mean metrics for QIDs
#
#            no IDF       IDF          LModel
# Precision: 0.1333333333 0.2333333333 0.2333333333
# Recall:    0.3000000000 0.5000000000 0.5000000000
# F-measure: 0.1841269841 0.3174603175 0.3174603175
# NDCG-10:   0.3894656935 0.5498972575 0.5539494423
# NDCG:      0.5499483271 0.6912132071 0.6732831202
